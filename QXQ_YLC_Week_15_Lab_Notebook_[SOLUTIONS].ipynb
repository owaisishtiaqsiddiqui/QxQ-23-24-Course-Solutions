# %% [markdown]
# <a href="https://colab.research.google.com/github/owaisishtiaqsiddiqui/QxQ-23-24-Course-Solutions/blob/main/QXQ_YLC_Week_15_Lab_Notebook_%5BSOLUTIONS%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab 14: Complexity of Algorithms**
# ---
#
# ### **Description**
# Today, we will work with two of the most famous classical search algorithms: linear and binary search. We will implement and analyze their performance.
#
#
#
# <br>
#
# ### **Structure**
# ### **Structure**
# **Part 1**: [Linear Search](#p1)
#
# **Part 2**: [Binary Search](#p2)
#
#
# <br>
#
# ### **Learning Objectives**
# By the end of this lab, you will:
# * Recognize how to compare algorithms using big-O notation.
# * Recognize the limits of classical search algorithms for unordered lists.
#
#
# <br>
#
# ### **Resources**
# * [Linear Search as a Dance](http://www.youtube.com/watch?v=-PuqKbu9K3U)
#
# * [Binary Search as a Dance](http://www.youtube.com/watch?v=wz7XgKowJIg)
#
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
# @title
# Importing other python libraries
import random
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ## **Part 1: Linear Search**
# ---
#
# In this section, we will implement and analyze the linear search algorithm.

# %% [markdown]
# #### **Problem #1.1**
#
# **Together**, let's run the code below to implement linear search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)
marked_item = random.choice(list_items)

print(list_items)
print(marked_item)

number_queries = 0
for item in list_items:

    number_queries = number_queries + 1

    if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break
# Out:
# range(0, 50)
# 40
# 40 has been found in 41 queries.

# %% [markdown]
# ###### **Solution**

# %%
list_items = range(50)

marked_item = random.choice(list_items)
number_queries = 0
for item in list_items:

    number_queries = number_queries + 1

    if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break
# Out:
# 48 has been found in 49 queries.

# %% [markdown]
# #### **Problem #1.2**
#
# **Together**, let's complete the code below to run our linear search many times to find the *worst number of queries*. We will use the following additional variables:
# * `number_trials`: The number of times to repeat the linear search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %%
number_trials = 1000
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)
  number_queries = 0
  for item in list_items:

      number_queries = # COMPLETE THIS LINE

      if item == marked_item:
          print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
          break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
#   File "<ipython-input-4-99970de007c6>", line 11
#     number_queries = # COMPLETE THIS LINE
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ###### **Solution**

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)
  number_queries = 0
  for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 33 has been found in 34 queries.
# 29 has been found in 30 queries.
# 34 has been found in 35 queries.
# 13 has been found in 14 queries.
# 23 has been found in 24 queries.
# 16 has been found in 17 queries.
# 40 has been found in 41 queries.
# 18 has been found in 19 queries.
# 29 has been found in 30 queries.
# 5 has been found in 6 queries.
# Worst number of queries: 41

# %% [markdown]
# #### **Problem #1.3**
#
# **Together**, let's put this code into a function called `linear_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %%
def linear_search(n):

  # COMPLETE THIS CODE

  return # COMPLETE THIS CODE

# %% [markdown]
# ###### **Solution**

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ### **Problem #1.4**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000.

# %%
linear_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [# COMPLETE THIS LINE

plt.scatter(ns, linear_queries, label = "linear")
plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear Search Worst Number of Queries with Increasing List Size")

plt.plot()
# Out:
#   File "<ipython-input-7-a3a8618c8c2e>", line 4
#     linear_queries += [# COMPLETE THIS LINE
#                       ^
# SyntaxError: '[' was never closed

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]

plt.scatter(ns, linear_queries, label = "linear")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Binary Search**
# ---
#
# In this section, we will implement and analyze the binary search algorithm. We will also visually compare it to the linear search algorithm we implemented above.

# %% [markdown]
# #### **Problem #2.1**
#
# **Together**, let's complete the code below to implement binary search for a list of numbers. We will use the following variables:
# * `list_items`: A list of numbers from 0 to 49 that we will search through.
# * `marked_item`: A randomly selected number from the list that we will search for.
# * `number_queries`: A count of how many times we need to query the list to find the marked item.

# %%
list_items = range(50)
marked_item = random.choice(list_items)

left = 0
right = len(list_items) - 1

number_queries = 0
for item in list_items:

  number_queries = # COMPLETE THIS LINE

  middle = int((left + right)/2)
  if list_items[middle] > marked_item:
    # COMPLETE THIS LINE
  elif list_items[middle] < marked_item:
    # COMPLETE THIS LINE
  else:
    print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
    break

# %% [markdown]
# ###### **Solution**

# %%
list_items = range(50)
marked_item = random.choice(list_items)

left = 0
right = len(list_items) - 1

number_queries = 0
for item in list_items:

  number_queries = number_queries + 1

  middle = int((left + right)/2)
  if list_items[middle] > marked_item:
    right = middle
  elif list_items[middle] < marked_item:
    left = middle
  else:
    print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
    break
# Out:
# 25 has been found in 5 queries.

# %% [markdown]
# #### **Problem #2.2**
#
# **Independently**, complete the code below to run our binary search many times to find the *worst number of queries*. You will use the following additional variables:
# * `number_trials`: The number of times to repeat the binary search.
# * `worst_query`: The most number of queries we had to make across all trials.

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  # ADD THE CODE FROM EXERCISE #1 HERE

  worst_query = # COMPLETE THIS LINE

print("Worst number of queries: " + str(worst_query))

# %% [markdown]
# ###### **Solution**

# %%
number_trials = 10
worst_query = 0
list_items = range(50)

for i in range(number_trials):

  marked_item = random.choice(list_items)

  left = 0
  right = len(list_items) - 1

  number_queries = 0
  for item in list_items:

    number_queries = number_queries + 1

    middle = int((left + right)/2)
    if list_items[middle] > marked_item:
      right = middle
    elif list_items[middle] < marked_item:
      left = middle
    else:
      print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
      break

  worst_query = max(worst_query, number_queries)

print("Worst number of queries: " + str(worst_query))
# Out:
# 40 has been found in 5 queries.
# 42 has been found in 3 queries.
# 42 has been found in 3 queries.
# 24 has been found in 1 queries.
# 17 has been found in 6 queries.
# 0 has been found in 6 queries.
# 8 has been found in 6 queries.
# 40 has been found in 5 queries.
# 44 has been found in 6 queries.
# 48 has been found in 6 queries.
# Worst number of queries: 6

# %% [markdown]
# #### **Problem #2.3**
#
# **Independently**, put this code into a function called `binary_search` such that it:
# * Takes `n` as input parameters.
# * Runs the code we wrote in Exercise #2 such that there are `n` items in `list_items`.
# * Returns the worst number of queries instead of printing it.

# %%
def binary_search(n):

  # ADD THE CODE FROM EXERCISE #1 HERE

  return # COMPLETE THIS LINE

# %% [markdown]
# ###### **Solution**

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = range(n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ---
# ####**Wait for your instructor to continue.**
#
# ---

# %% [markdown]
# #### **Problem #2.4**
#
# **Together**, graph the worst number of queries for list sizes from 100 to 10000.

# %%
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  # COMPLETE THIS LINE

plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()

# %% [markdown]
# ###### **Solution**

# %%
# Importing  python libraries
import random
import matplotlib.pyplot as plt



binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  binary_queries += [binary_search(n)]

plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 37 has been found in 6 queries.
# 95 has been found in 5 queries.
# 31 has been found in 6 queries.
# 87 has been found in 6 queries.
# 75 has been found in 6 queries.
# 0 has been found in 7 queries.
# 13 has been found in 6 queries.
# 49 has been found in 1 queries.
# 74 has been found in 2 queries.
# 74 has been found in 3 queries.
# 28 has been found in 7 queries.
# 196 has been found in 8 queries.
# 120 has been found in 6 queries.
# 108 has been found in 6 queries.
# 159 has been found in 7 queries.
# 27 has been found in 6 queries.
# 83 has been found in 6 queries.
# 27 has been found in 6 queries.
# 155 has been found in 5 queries.
# 65 has been found in 8 queries.
# 280 has been found in 4 queries.
# 7 has been found in 8 queries.
# 249 has been found in 8 queries.
# 105 has been found in 9 queries.
# 233 has been found in 5 queries.
# 193 has been found in 8 queries.
# 164 has been found in 7 queries.
# 63 has been found in 9 queries.
# 248 has been found in 7 queries.
# 300 has been found in 8 queries.
# 225 has been found in 8 queries.
# 225 has been found in 8 queries.
# 281 has been found in 8 queries.
# 287 has been found in 8 queries.
# 217 has been found in 6 queries.
# 122 has been found in 8 queries.
# 344 has been found in 9 queries.
# 151 has been found in 9 queries.
# 90 has been found in 8 queries.
# 378 has been found in 9 queries.
# 121 has been found in 9 queries.
# 401 has been found in 7 queries.
# 248 has been found in 9 queries.
# 20 has been found in 9 queries.
# 437 has been found in 8 queries.
# 326 has been found in 5 queries.
# 71 has been found in 8 queries.
# 147 has been found in 6 queries.
# 279 has been found in 9 queries.
# 191 has been found in 9 queries.
# 586 has been found in 8 queries.
# 120 has been found in 6 queries.
# 417 has been found in 8 queries.
# 217 has been found in 9 queries.
# 55 has been found in 5 queries.
# 526 has been found in 8 queries.
# 467 has been found in 5 queries.
# 256 has been found in 7 queries.
# 58 has been found in 9 queries.
# 230 has been found in 8 queries.
# 275 has been found in 9 queries.
# 596 has been found in 10 queries.
# 485 has been found in 7 queries.
# 61 has been found in 10 queries.
# 65 has been found in 5 queries.
# 37 has been found in 7 queries.
# 585 has been found in 10 queries.
# 335 has been found in 8 queries.
# 631 has been found in 9 queries.
# 353 has been found in 9 queries.
# 110 has been found in 10 queries.
# 235 has been found in 10 queries.
# 676 has been found in 10 queries.
# 609 has been found in 9 queries.
# 393 has been found in 9 queries.
# 576 has been found in 10 queries.
# 103 has been found in 9 queries.
# 400 has been found in 9 queries.
# 136 has been found in 6 queries.
# 533 has been found in 5 queries.
# 199 has been found in 8 queries.
# 614 has been found in 10 queries.
# 326 has been found in 10 queries.
# 29 has been found in 9 queries.
# 858 has been found in 10 queries.
# 162 has been found in 9 queries.
# 212 has been found in 10 queries.
# 641 has been found in 8 queries.
# 621 has been found in 10 queries.
# 527 has been found in 10 queries.
# 725 has been found in 7 queries.
# 913 has been found in 10 queries.
# 145 has been found in 9 queries.
# 783 has been found in 8 queries.
# 872 has been found in 9 queries.
# 807 has been found in 8 queries.
# 518 has been found in 8 queries.
# 845 has been found in 10 queries.
# 129 has been found in 9 queries.
# 1039 has been found in 10 queries.
# 548 has been found in 11 queries.
# 389 has been found in 10 queries.
# 940 has been found in 9 queries.
# 1097 has been found in 10 queries.
# 1060 has been found in 10 queries.
# 1042 has been found in 8 queries.
# 192 has been found in 8 queries.
# 371 has been found in 8 queries.
# 493 has been found in 10 queries.
# 972 has been found in 10 queries.
# 752 has been found in 10 queries.
# 816 has been found in 9 queries.
# 953 has been found in 10 queries.
# 978 has been found in 8 queries.
# 1115 has been found in 10 queries.
# 409 has been found in 10 queries.
# 655 has been found in 6 queries.
# 48 has been found in 9 queries.
# 32 has been found in 8 queries.
# 1292 has been found in 11 queries.
# 832 has been found in 10 queries.
# 1271 has been found in 10 queries.
# 203 has been found in 10 queries.
# 860 has been found in 11 queries.
# 320 has been found in 11 queries.
# 1078 has been found in 10 queries.
# 796 has been found in 10 queries.
# 264 has been found in 10 queries.
# 652 has been found in 10 queries.
# 847 has been found in 10 queries.
# 1232 has been found in 10 queries.
# 705 has been found in 10 queries.
# 137 has been found in 11 queries.
# 908 has been found in 9 queries.
# 1366 has been found in 7 queries.
# 1150 has been found in 10 queries.
# 401 has been found in 10 queries.
# 1051 has been found in 9 queries.
# 1317 has been found in 10 queries.
# 1159 has been found in 10 queries.
# 493 has been found in 9 queries.
# 788 has been found in 11 queries.
# 1213 has been found in 11 queries.
# 1345 has been found in 11 queries.
# 1288 has been found in 10 queries.
# 206 has been found in 11 queries.
# 1257 has been found in 11 queries.
# 858 has been found in 11 queries.
# 427 has been found in 11 queries.
# 1401 has been found in 11 queries.
# 505 has been found in 8 queries.
# 1508 has been found in 9 queries.
# 993 has been found in 10 queries.
# 1305 has been found in 8 queries.
# 1518 has been found in 10 queries.
# 1394 has been found in 11 queries.
# 1027 has been found in 9 queries.
# 1273 has been found in 11 queries.
# 1459 has been found in 10 queries.
# 20 has been found in 10 queries.
# 1118 has been found in 10 queries.
# 1621 has been found in 9 queries.
# 150 has been found in 10 queries.
# 226 has been found in 10 queries.
# 303 has been found in 11 queries.
# 243 has been found in 11 queries.
# 637 has been found in 10 queries.
# 1382 has been found in 11 queries.
# 1693 has been found in 10 queries.
# 693 has been found in 10 queries.
# 754 has been found in 9 queries.
# 1677 has been found in 10 queries.
# 1798 has been found in 11 queries.
# 469 has been found in 11 queries.
# 1797 has been found in 10 queries.
# 549 has been found in 11 queries.
# 1691 has been found in 10 queries.
# 645 has been found in 6 queries.
# 802 has been found in 11 queries.
# 247 has been found in 9 queries.
# 651 has been found in 5 queries.
# 1092 has been found in 9 queries.
# 715 has been found in 11 queries.
# 843 has been found in 11 queries.
# 1498 has been found in 10 queries.
# 1757 has been found in 8 queries.
# 631 has been found in 11 queries.
# 910 has been found in 11 queries.
# 1299 has been found in 10 queries.
# 214 has been found in 11 queries.
# 1230 has been found in 11 queries.
# 1680 has been found in 10 queries.
# 1854 has been found in 9 queries.
# 1915 has been found in 11 queries.
# 1065 has been found in 11 queries.
# 492 has been found in 11 queries.
# 304 has been found in 11 queries.
# 166 has been found in 9 queries.
# 1830 has been found in 9 queries.
# 329 has been found in 10 queries.
# 1239 has been found in 11 queries.
# 486 has been found in 9 queries.
# 1525 has been found in 11 queries.
# 989 has been found in 10 queries.
# 1469 has been found in 11 queries.
# 1754 has been found in 11 queries.
# 1971 has been found in 9 queries.
# 1010 has been found in 11 queries.
# 1036 has been found in 9 queries.
# 858 has been found in 6 queries.
# 1746 has been found in 9 queries.
# 1292 has been found in 11 queries.
# 1380 has been found in 10 queries.
# 476 has been found in 11 queries.
# 1058 has been found in 11 queries.
# 195 has been found in 11 queries.
# 1989 has been found in 10 queries.
# 1380 has been found in 10 queries.
# 1428 has been found in 11 queries.
# 251 has been found in 6 queries.
# 1966 has been found in 8 queries.
# 1145 has been found in 11 queries.
# 2028 has been found in 12 queries.
# 1060 has been found in 11 queries.
# 474 has been found in 12 queries.
# 1156 has been found in 11 queries.
# 591 has been found in 7 queries.
# 1096 has been found in 11 queries.
# 1460 has been found in 10 queries.
# 1454 has been found in 11 queries.
# 1370 has been found in 11 queries.
# 268 has been found in 11 queries.
# 2186 has been found in 11 queries.
# 2078 has been found in 11 queries.
# 1097 has been found in 10 queries.
# 30 has been found in 11 queries.
# 23 has been found in 11 queries.
# 2009 has been found in 9 queries.
# 1585 has been found in 10 queries.
# 2384 has been found in 11 queries.
# 395 has been found in 11 queries.
# 402 has been found in 11 queries.
# 2392 has been found in 10 queries.
# 2265 has been found in 11 queries.
# 353 has been found in 10 queries.
# 2448 has been found in 12 queries.
# 105 has been found in 11 queries.
# 264 has been found in 11 queries.
# 558 has been found in 11 queries.
# 2411 has been found in 11 queries.
# 43 has been found in 11 queries.
# 2198 has been found in 11 queries.
# 1293 has been found in 9 queries.
# 2242 has been found in 12 queries.
# 1685 has been found in 11 queries.
# 2164 has been found in 11 queries.
# 1311 has been found in 10 queries.
# 75 has been found in 9 queries.
# 2516 has been found in 12 queries.
# 1567 has been found in 11 queries.
# 73 has been found in 8 queries.
# 1815 has been found in 11 queries.
# 749 has been found in 10 queries.
# 472 has been found in 12 queries.
# 994 has been found in 9 queries.
# 1859 has been found in 12 queries.
# 814 has been found in 12 queries.
# 1495 has been found in 12 queries.
# 2509 has been found in 11 queries.
# 427 has been found in 10 queries.
# 166 has been found in 11 queries.
# 1049 has been found in 3 queries.
# 1606 has been found in 8 queries.
# 647 has been found in 11 queries.
# 177 has been found in 11 queries.
# 2235 has been found in 9 queries.
# 620 has been found in 11 queries.
# 1092 has been found in 6 queries.
# 1147 has been found in 8 queries.
# 223 has been found in 10 queries.
# 2225 has been found in 11 queries.
# 467 has been found in 12 queries.
# 2020 has been found in 11 queries.
# 1727 has been found in 12 queries.
# 2088 has been found in 9 queries.
# 1231 has been found in 12 queries.
# 2483 has been found in 12 queries.
# 2875 has been found in 12 queries.
# 2589 has been found in 10 queries.
# 2839 has been found in 12 queries.
# 2921 has been found in 12 queries.
# 287 has been found in 12 queries.
# 853 has been found in 8 queries.
# 2612 has been found in 8 queries.
# 2376 has been found in 12 queries.
# 2941 has been found in 11 queries.
# 1493 has been found in 9 queries.
# 2548 has been found in 11 queries.
# 911 has been found in 12 queries.
# 1293 has been found in 12 queries.
# 1568 has been found in 11 queries.
# 866 has been found in 12 queries.
# 2745 has been found in 11 queries.
# 2831 has been found in 12 queries.
# 2033 has been found in 5 queries.
# 877 has been found in 11 queries.
# 84 has been found in 8 queries.
# 2502 has been found in 11 queries.
# 405 has been found in 9 queries.
# 1482 has been found in 12 queries.
# 792 has been found in 9 queries.
# 2740 has been found in 11 queries.
# 618 has been found in 11 queries.
# 259 has been found in 11 queries.
# 2759 has been found in 11 queries.
# 533 has been found in 10 queries.
# 1536 has been found in 8 queries.
# 3134 has been found in 11 queries.
# 1452 has been found in 10 queries.
# 506 has been found in 11 queries.
# 519 has been found in 11 queries.
# 1985 has been found in 12 queries.
# 2423 has been found in 11 queries.
# 1446 has been found in 11 queries.
# 2570 has been found in 9 queries.
# 1630 has been found in 11 queries.
# 236 has been found in 12 queries.
# 1112 has been found in 12 queries.
# 457 has been found in 11 queries.
# 2705 has been found in 12 queries.
# 2730 has been found in 10 queries.
# 1611 has been found in 9 queries.
# 2151 has been found in 11 queries.
# 1020 has been found in 12 queries.
# 874 has been found in 12 queries.
# 1698 has been found in 12 queries.
# 2399 has been found in 12 queries.
# 438 has been found in 11 queries.
# 1566 has been found in 11 queries.
# 949 has been found in 11 queries.
# 840 has been found in 11 queries.
# 3132 has been found in 12 queries.
# 196 has been found in 12 queries.
# 1646 has been found in 11 queries.
# 2169 has been found in 12 queries.
# 3103 has been found in 12 queries.
# 1608 has been found in 12 queries.
# 3306 has been found in 12 queries.
# 2775 has been found in 12 queries.
# 3505 has been found in 11 queries.
# 962 has been found in 9 queries.
# 2340 has been found in 9 queries.
# 3056 has been found in 12 queries.
# 134 has been found in 11 queries.
# 639 has been found in 11 queries.
# 2434 has been found in 10 queries.
# 2478 has been found in 12 queries.
# 495 has been found in 12 queries.
# 1008 has been found in 12 queries.
# 1120 has been found in 11 queries.
# 702 has been found in 12 queries.
# 1073 has been found in 11 queries.
# 2105 has been found in 12 queries.
# 3127 has been found in 9 queries.
# 2525 has been found in 11 queries.
# 1944 has been found in 12 queries.
# 3178 has been found in 6 queries.
# 835 has been found in 11 queries.
# 3326 has been found in 12 queries.
# 354 has been found in 12 queries.
# 1972 has been found in 8 queries.
# 1508 has been found in 10 queries.
# 3342 has been found in 12 queries.
# 1255 has been found in 12 queries.
# 1827 has been found in 10 queries.
# 2980 has been found in 12 queries.
# 3653 has been found in 10 queries.
# 284 has been found in 10 queries.
# 2692 has been found in 9 queries.
# 224 has been found in 12 queries.
# 593 has been found in 12 queries.
# 249 has been found in 12 queries.
# 44 has been found in 12 queries.
# 1804 has been found in 12 queries.
# 1588 has been found in 11 queries.
# 1214 has been found in 12 queries.
# 3644 has been found in 12 queries.
# 1327 has been found in 10 queries.
# 1902 has been found in 12 queries.
# 1126 has been found in 12 queries.
# 2241 has been found in 9 queries.
# 701 has been found in 8 queries.
# 3711 has been found in 11 queries.
# 3814 has been found in 10 queries.
# 2228 has been found in 12 queries.
# 1590 has been found in 11 queries.
# 2841 has been found in 12 queries.
# 1096 has been found in 10 queries.
# 1704 has been found in 12 queries.
# 1534 has been found in 11 queries.
# 766 has been found in 11 queries.
# 1808 has been found in 8 queries.
# 833 has been found in 12 queries.
# 3138 has been found in 6 queries.
# 3410 has been found in 8 queries.
# 2210 has been found in 12 queries.
# 1196 has been found in 10 queries.
# 1927 has been found in 12 queries.
# 2864 has been found in 12 queries.
# 2921 has been found in 12 queries.
# 1001 has been found in 11 queries.
# 1621 has been found in 12 queries.
# 2909 has been found in 12 queries.
# 3126 has been found in 11 queries.
# 2558 has been found in 6 queries.
# 1717 has been found in 10 queries.
# 3513 has been found in 10 queries.
# 1564 has been found in 12 queries.
# 234 has been found in 12 queries.
# 370 has been found in 11 queries.
# 3201 has been found in 12 queries.
# 2070 has been found in 11 queries.
# 558 has been found in 12 queries.
# 3206 has been found in 13 queries.
# 1751 has been found in 11 queries.
# 3415 has been found in 12 queries.
# 2718 has been found in 13 queries.
# 2405 has been found in 12 queries.
# 3082 has been found in 11 queries.
# 2807 has been found in 12 queries.
# 706 has been found in 12 queries.
# 2513 has been found in 12 queries.
# 4008 has been found in 12 queries.
# 1134 has been found in 12 queries.
# 2886 has been found in 5 queries.
# 3638 has been found in 12 queries.
# 3142 has been found in 13 queries.
# 3813 has been found in 13 queries.
# 1775 has been found in 12 queries.
# 2909 has been found in 11 queries.
# 1773 has been found in 8 queries.
# 1495 has been found in 12 queries.
# 3708 has been found in 12 queries.
# 2925 has been found in 12 queries.
# 4265 has been found in 12 queries.
# 3804 has been found in 12 queries.
# 1230 has been found in 12 queries.
# 661 has been found in 12 queries.
# 2148 has been found in 12 queries.
# 3584 has been found in 12 queries.
# 1428 has been found in 12 queries.
# 614 has been found in 12 queries.
# 4187 has been found in 11 queries.
# 2657 has been found in 13 queries.
# 2602 has been found in 12 queries.
# 4504 has been found in 10 queries.
# 1081 has been found in 10 queries.
# 3250 has been found in 13 queries.
# 696 has been found in 11 queries.
# 4563 has been found in 11 queries.
# 749 has been found in 12 queries.
# 3964 has been found in 5 queries.
# 91 has been found in 8 queries.
# 3634 has been found in 12 queries.
# 2256 has been found in 8 queries.
# 4123 has been found in 12 queries.
# 4582 has been found in 12 queries.
# 2497 has been found in 11 queries.
# 912 has been found in 12 queries.
# 3222 has been found in 12 queries.
# 2747 has been found in 11 queries.
# 3153 has been found in 10 queries.
# 760 has been found in 11 queries.
# 1476 has been found in 12 queries.
# 4415 has been found in 12 queries.
# 3498 has been found in 12 queries.
# 2946 has been found in 10 queries.
# 3905 has been found in 11 queries.
# 847 has been found in 12 queries.
# 2429 has been found in 8 queries.
# 2639 has been found in 13 queries.
# 3752 has been found in 11 queries.
# 3029 has been found in 12 queries.
# 2839 has been found in 13 queries.
# 4843 has been found in 11 queries.
# 1480 has been found in 13 queries.
# 3244 has been found in 11 queries.
# 1326 has been found in 12 queries.
# 841 has been found in 6 queries.
# 2185 has been found in 13 queries.
# 3053 has been found in 13 queries.
# 3520 has been found in 11 queries.
# 3619 has been found in 12 queries.
# 4742 has been found in 12 queries.
# 2744 has been found in 11 queries.
# 4614 has been found in 11 queries.
# 3964 has been found in 12 queries.
# 4978 has been found in 13 queries.
# 4872 has been found in 12 queries.
# 1405 has been found in 11 queries.
# 1479 has been found in 11 queries.
# 4991 has been found in 11 queries.
# 1807 has been found in 12 queries.
# 80 has been found in 12 queries.
# 2799 has been found in 11 queries.
# 2687 has been found in 13 queries.
# 676 has been found in 7 queries.
# 3722 has been found in 12 queries.
# 3215 has been found in 9 queries.
# 2532 has been found in 10 queries.
# 2842 has been found in 6 queries.
# 4271 has been found in 11 queries.
# 3841 has been found in 13 queries.
# 2413 has been found in 12 queries.
# 3126 has been found in 7 queries.
# 2581 has been found in 12 queries.
# 120 has been found in 13 queries.
# 1164 has been found in 12 queries.
# 4848 has been found in 10 queries.
# 559 has been found in 12 queries.
# 4824 has been found in 12 queries.
# 4160 has been found in 12 queries.
# 1179 has been found in 12 queries.
# 3054 has been found in 12 queries.
# 4114 has been found in 13 queries.
# 1776 has been found in 12 queries.
# 2331 has been found in 13 queries.
# 1539 has been found in 13 queries.
# 513 has been found in 11 queries.
# 2838 has been found in 12 queries.
# 2466 has been found in 8 queries.
# 2431 has been found in 11 queries.
# 1439 has been found in 12 queries.
# 4895 has been found in 12 queries.
# 3615 has been found in 9 queries.
# 765 has been found in 11 queries.
# 4747 has been found in 11 queries.
# 2886 has been found in 12 queries.
# 1362 has been found in 12 queries.
# 2875 has been found in 12 queries.
# 1750 has been found in 12 queries.
# 4306 has been found in 12 queries.
# 1353 has been found in 12 queries.
# 4759 has been found in 11 queries.
# 4859 has been found in 10 queries.
# 1962 has been found in 12 queries.
# 4656 has been found in 13 queries.
# 225 has been found in 12 queries.
# 3126 has been found in 11 queries.
# 4012 has been found in 13 queries.
# 3249 has been found in 11 queries.
# 5189 has been found in 12 queries.
# 4115 has been found in 13 queries.
# 4603 has been found in 9 queries.
# 69 has been found in 13 queries.
# 5148 has been found in 12 queries.
# 1423 has been found in 12 queries.
# 3417 has been found in 12 queries.
# 3544 has been found in 11 queries.
# 2376 has been found in 13 queries.
# 5198 has been found in 12 queries.
# 1766 has been found in 12 queries.
# 4510 has been found in 12 queries.
# 3412 has been found in 13 queries.
# 3477 has been found in 10 queries.
# 717 has been found in 10 queries.
# 1509 has been found in 13 queries.
# 4443 has been found in 11 queries.
# 4189 has been found in 10 queries.
# 307 has been found in 11 queries.
# 5750 has been found in 11 queries.
# 5085 has been found in 9 queries.
# 5358 has been found in 11 queries.
# 2088 has been found in 10 queries.
# 3765 has been found in 12 queries.
# 5545 has been found in 11 queries.
# 5797 has been found in 12 queries.
# 2779 has been found in 10 queries.
# 649 has been found in 10 queries.
# 1743 has been found in 13 queries.
# 768 has been found in 11 queries.
# 3861 has been found in 11 queries.
# 4873 has been found in 12 queries.
# 161 has been found in 8 queries.
# 5882 has been found in 12 queries.
# 4581 has been found in 13 queries.
# 187 has been found in 12 queries.
# 3958 has been found in 13 queries.
# 5493 has been found in 13 queries.
# 4582 has been found in 13 queries.
# 4464 has been found in 12 queries.
# 4078 has been found in 12 queries.
# 610 has been found in 11 queries.
# 360 has been found in 12 queries.
# 2929 has been found in 12 queries.
# 2117 has been found in 12 queries.
# 5908 has been found in 12 queries.
# 3632 has been found in 12 queries.
# 2417 has been found in 13 queries.
# 3267 has been found in 13 queries.
# 238 has been found in 12 queries.
# 2768 has been found in 10 queries.
# 422 has been found in 10 queries.
# 2763 has been found in 12 queries.
# 3607 has been found in 13 queries.
# 2784 has been found in 12 queries.
# 1957 has been found in 13 queries.
# 4421 has been found in 11 queries.
# 2799 has been found in 12 queries.
# 45 has been found in 11 queries.
# 4899 has been found in 11 queries.
# 709 has been found in 13 queries.
# 1545 has been found in 11 queries.
# 4757 has been found in 9 queries.
# 2628 has been found in 13 queries.
# 512 has been found in 13 queries.
# 4673 has been found in 8 queries.
# 2944 has been found in 11 queries.
# 5314 has been found in 9 queries.
# 3463 has been found in 13 queries.
# 2274 has been found in 9 queries.
# 474 has been found in 13 queries.
# 4034 has been found in 6 queries.
# 100 has been found in 13 queries.
# 2945 has been found in 10 queries.
# 5255 has been found in 12 queries.
# 84 has been found in 13 queries.
# 1272 has been found in 12 queries.
# 266 has been found in 11 queries.
# 529 has been found in 13 queries.
# 5899 has been found in 6 queries.
# 5189 has been found in 11 queries.
# 897 has been found in 12 queries.
# 4459 has been found in 12 queries.
# 1156 has been found in 12 queries.
# 4863 has been found in 13 queries.
# 5483 has been found in 11 queries.
# 1155 has been found in 10 queries.
# 4811 has been found in 9 queries.
# 289 has been found in 12 queries.
# 2507 has been found in 11 queries.
# 6140 has been found in 12 queries.
# 4410 has been found in 12 queries.
# 4851 has been found in 11 queries.
# 2829 has been found in 9 queries.
# 1344 has been found in 8 queries.
# 2644 has been found in 13 queries.
# 3691 has been found in 13 queries.
# 2045 has been found in 11 queries.
# 4466 has been found in 13 queries.
# 3226 has been found in 13 queries.
# 4711 has been found in 13 queries.
# 1252 has been found in 12 queries.
# 3442 has been found in 13 queries.
# 1201 has been found in 12 queries.
# 1712 has been found in 13 queries.
# 6337 has been found in 13 queries.
# 1327 has been found in 12 queries.
# 2106 has been found in 12 queries.
# 4891 has been found in 13 queries.
# 1241 has been found in 9 queries.
# 1064 has been found in 13 queries.
# 1669 has been found in 13 queries.
# 5750 has been found in 12 queries.
# 2005 has been found in 13 queries.
# 1445 has been found in 13 queries.
# 4497 has been found in 13 queries.
# 3563 has been found in 13 queries.
# 787 has been found in 11 queries.
# 6438 has been found in 12 queries.
# 5642 has been found in 13 queries.
# 3972 has been found in 11 queries.
# 2817 has been found in 11 queries.
# 328 has been found in 13 queries.
# 394 has been found in 13 queries.
# 5303 has been found in 13 queries.
# 3912 has been found in 11 queries.
# 3774 has been found in 12 queries.
# 4765 has been found in 13 queries.
# 1314 has been found in 13 queries.
# 6260 has been found in 11 queries.
# 3341 has been found in 6 queries.
# 6597 has been found in 13 queries.
# 4611 has been found in 12 queries.
# 6652 has been found in 11 queries.
# 5369 has been found in 12 queries.
# 5022 has been found in 13 queries.
# 5981 has been found in 13 queries.
# 4383 has been found in 13 queries.
# 2413 has been found in 13 queries.
# 3575 has been found in 13 queries.
# 6760 has been found in 12 queries.
# 1469 has been found in 12 queries.
# 1710 has been found in 11 queries.
# 6294 has been found in 12 queries.
# 5772 has been found in 12 queries.
# 3098 has been found in 13 queries.
# 2995 has been found in 11 queries.
# 951 has been found in 11 queries.
# 5426 has been found in 13 queries.
# 1655 has been found in 13 queries.
# 605 has been found in 11 queries.
# 691 has been found in 13 queries.
# 2226 has been found in 11 queries.
# 3121 has been found in 11 queries.
# 3007 has been found in 9 queries.
# 3566 has been found in 13 queries.
# 5510 has been found in 10 queries.
# 69 has been found in 12 queries.
# 1205 has been found in 13 queries.
# 1233 has been found in 13 queries.
# 4230 has been found in 13 queries.
# 1515 has been found in 12 queries.
# 6214 has been found in 8 queries.
# 5116 has been found in 13 queries.
# 725 has been found in 13 queries.
# 108 has been found in 11 queries.
# 5713 has been found in 12 queries.
# 4252 has been found in 10 queries.
# 7143 has been found in 13 queries.
# 1610 has been found in 9 queries.
# 636 has been found in 13 queries.
# 1138 has been found in 12 queries.
# 5893 has been found in 13 queries.
# 519 has been found in 13 queries.
# 5712 has been found in 11 queries.
# 4019 has been found in 8 queries.
# 1465 has been found in 12 queries.
# 2205 has been found in 13 queries.
# 5013 has been found in 9 queries.
# 6890 has been found in 12 queries.
# 4959 has been found in 13 queries.
# 1587 has been found in 13 queries.
# 6782 has been found in 13 queries.
# 538 has been found in 12 queries.
# 6397 has been found in 11 queries.
# 2707 has been found in 13 queries.
# 4314 has been found in 13 queries.
# 7337 has been found in 11 queries.
# 2243 has been found in 13 queries.
# 5520 has been found in 9 queries.
# 909 has been found in 13 queries.
# 1083 has been found in 8 queries.
# 382 has been found in 13 queries.
# 5560 has been found in 13 queries.
# 2335 has been found in 13 queries.
# 5473 has been found in 13 queries.
# 6173 has been found in 12 queries.
# 5215 has been found in 13 queries.
# 6968 has been found in 13 queries.
# 7174 has been found in 13 queries.
# 2045 has been found in 13 queries.
# 563 has been found in 12 queries.
# 2240 has been found in 9 queries.
# 7287 has been found in 12 queries.
# 4014 has been found in 13 queries.
# 705 has been found in 12 queries.
# 6076 has been found in 10 queries.
# 6377 has been found in 11 queries.
# 1834 has been found in 12 queries.
# 7489 has been found in 12 queries.
# 35 has been found in 12 queries.
# 3265 has been found in 13 queries.
# 3167 has been found in 11 queries.
# 6526 has been found in 12 queries.
# 2955 has been found in 12 queries.
# 506 has been found in 13 queries.
# 6999 has been found in 13 queries.
# 2989 has been found in 12 queries.
# 68 has been found in 13 queries.
# 5479 has been found in 11 queries.
# 6946 has been found in 12 queries.
# 442 has been found in 12 queries.
# 6020 has been found in 13 queries.
# 3945 has been found in 12 queries.
# 5925 has been found in 12 queries.
# 475 has been found in 11 queries.
# 7692 has been found in 9 queries.
# 1079 has been found in 9 queries.
# 5899 has been found in 13 queries.
# 1643 has been found in 12 queries.
# 686 has been found in 13 queries.
# 6349 has been found in 12 queries.
# 5518 has been found in 11 queries.
# 6679 has been found in 9 queries.
# 1629 has been found in 13 queries.
# 3433 has been found in 12 queries.
# 3848 has been found in 10 queries.
# 2084 has been found in 13 queries.
# 3940 has been found in 13 queries.
# 237 has been found in 11 queries.
# 5239 has been found in 12 queries.
# 7481 has been found in 12 queries.
# 6201 has been found in 9 queries.
# 4232 has been found in 13 queries.
# 7360 has been found in 12 queries.
# 7161 has been found in 13 queries.
# 7779 has been found in 13 queries.
# 6993 has been found in 12 queries.
# 1138 has been found in 6 queries.
# 6165 has been found in 13 queries.
# 2332 has been found in 10 queries.
# 3174 has been found in 13 queries.
# 1552 has been found in 13 queries.
# 1892 has been found in 13 queries.
# 6770 has been found in 13 queries.
# 2670 has been found in 13 queries.
# 5726 has been found in 12 queries.
# 992 has been found in 11 queries.
# 4842 has been found in 13 queries.
# 5471 has been found in 13 queries.
# 4604 has been found in 13 queries.
# 2874 has been found in 13 queries.
# 1454 has been found in 12 queries.
# 2991 has been found in 12 queries.
# 2167 has been found in 12 queries.
# 3109 has been found in 13 queries.
# 6702 has been found in 13 queries.
# 4704 has been found in 13 queries.
# 4298 has been found in 11 queries.
# 1894 has been found in 13 queries.
# 5468 has been found in 13 queries.
# 7666 has been found in 9 queries.
# 5434 has been found in 12 queries.
# 2876 has been found in 13 queries.
# 4451 has been found in 13 queries.
# 7181 has been found in 12 queries.
# 6965 has been found in 13 queries.
# 5240 has been found in 12 queries.
# 6993 has been found in 12 queries.
# 2656 has been found in 8 queries.
# 5801 has been found in 13 queries.
# 7887 has been found in 13 queries.
# 6475 has been found in 13 queries.
# 3730 has been found in 10 queries.
# 1170 has been found in 13 queries.
# 5863 has been found in 10 queries.
# 3141 has been found in 13 queries.
# 6406 has been found in 13 queries.
# 4955 has been found in 12 queries.
# 8394 has been found in 11 queries.
# 5886 has been found in 13 queries.
# 471 has been found in 13 queries.
# 949 has been found in 11 queries.
# 2044 has been found in 11 queries.
# 5024 has been found in 13 queries.
# 2813 has been found in 12 queries.
# 715 has been found in 13 queries.
# 1146 has been found in 12 queries.
# 2805 has been found in 12 queries.
# 6579 has been found in 13 queries.
# 4639 has been found in 13 queries.
# 6629 has been found in 13 queries.
# 838 has been found in 8 queries.
# 1625 has been found in 12 queries.
# 1500 has been found in 10 queries.
# 3255 has been found in 13 queries.
# 5715 has been found in 12 queries.
# 8071 has been found in 12 queries.
# 7739 has been found in 13 queries.
# 2901 has been found in 12 queries.
# 106 has been found in 13 queries.
# 4417 has been found in 13 queries.
# 3227 has been found in 8 queries.
# 1486 has been found in 13 queries.
# 4594 has been found in 10 queries.
# 6522 has been found in 13 queries.
# 3701 has been found in 13 queries.
# 4069 has been found in 13 queries.
# 8309 has been found in 13 queries.
# 3301 has been found in 12 queries.
# 6394 has been found in 12 queries.
# 5121 has been found in 13 queries.
# 8768 has been found in 11 queries.
# 7746 has been found in 13 queries.
# 778 has been found in 12 queries.
# 3772 has been found in 13 queries.
# 2208 has been found in 13 queries.
# 6520 has been found in 14 queries.
# 925 has been found in 13 queries.
# 5574 has been found in 13 queries.
# 518 has been found in 12 queries.
# 4983 has been found in 13 queries.
# 7638 has been found in 10 queries.
# 7682 has been found in 13 queries.
# 5055 has been found in 14 queries.
# 5820 has been found in 14 queries.
# 434 has been found in 9 queries.
# 1609 has been found in 13 queries.
# 4444 has been found in 14 queries.
# 7913 has been found in 11 queries.
# 4418 has been found in 14 queries.
# 8697 has been found in 13 queries.
# 5437 has been found in 14 queries.
# 1559 has been found in 12 queries.
# 3320 has been found in 9 queries.
# 208 has been found in 13 queries.
# 746 has been found in 13 queries.
# 2807 has been found in 13 queries.
# 3969 has been found in 13 queries.
# 1024 has been found in 11 queries.
# 5098 has been found in 14 queries.
# 5294 has been found in 8 queries.
# 4294 has been found in 11 queries.
# 5624 has been found in 13 queries.
# 186 has been found in 10 queries.
# 1760 has been found in 12 queries.
# 2733 has been found in 13 queries.
# 3092 has been found in 12 queries.
# 2324 has been found in 14 queries.
# 145 has been found in 12 queries.
# 275 has been found in 12 queries.
# 7426 has been found in 12 queries.
# 807 has been found in 9 queries.
# 8489 has been found in 10 queries.
# 6577 has been found in 12 queries.
# 4989 has been found in 11 queries.
# 1935 has been found in 13 queries.
# 1532 has been found in 12 queries.
# 1167 has been found in 13 queries.
# 7213 has been found in 11 queries.
# 6252 has been found in 12 queries.
# 5829 has been found in 9 queries.
# 17 has been found in 14 queries.
# 7857 has been found in 13 queries.
# 4341 has been found in 12 queries.
# 1771 has been found in 13 queries.
# 2547 has been found in 12 queries.
# 4875 has been found in 10 queries.
# 6748 has been found in 13 queries.
# 6214 has been found in 12 queries.
# 6287 has been found in 13 queries.
# 4730 has been found in 11 queries.
# 2764 has been found in 13 queries.
# 1012 has been found in 11 queries.
# 4012 has been found in 13 queries.
# 1209 has been found in 14 queries.
# 7616 has been found in 14 queries.
# 549 has been found in 14 queries.
# 4013 has been found in 13 queries.
# 907 has been found in 14 queries.
# 8186 has been found in 12 queries.
# 1430 has been found in 13 queries.
# 1074 has been found in 14 queries.
# 4244 has been found in 12 queries.
# 731 has been found in 10 queries.
# 1993 has been found in 13 queries.
# 2424 has been found in 11 queries.
# 5703 has been found in 10 queries.
# 693 has been found in 13 queries.
# 3708 has been found in 12 queries.
# 9100 has been found in 14 queries.
# 8409 has been found in 13 queries.
# 2264 has been found in 12 queries.
# 3516 has been found in 12 queries.
# 2247 has been found in 13 queries.
# 31 has been found in 14 queries.
# 6114 has been found in 13 queries.
# 6696 has been found in 11 queries.
# 1495 has been found in 14 queries.
# 2599 has been found in 13 queries.
# 6466 has been found in 14 queries.
# 529 has been found in 14 queries.
# 6430 has been found in 13 queries.
# 8720 has been found in 13 queries.
# 3979 has been found in 13 queries.
# 9502 has been found in 13 queries.
# 5431 has been found in 11 queries.
# 3862 has been found in 14 queries.
# 7988 has been found in 14 queries.
# 9734 has been found in 13 queries.
# 3629 has been found in 14 queries.
# 4544 has been found in 13 queries.
# 6820 has been found in 14 queries.
# 1136 has been found in 14 queries.
# 726 has been found in 8 queries.
# 2460 has been found in 12 queries.
# 7984 has been found in 11 queries.
# 1908 has been found in 13 queries.
# 9015 has been found in 13 queries.
# 7087 has been found in 13 queries.
# 2783 has been found in 5 queries.
# 7518 has been found in 13 queries.
# 7556 has been found in 13 queries.
# 8020 has been found in 13 queries.
# 2895 has been found in 12 queries.
# 15 has been found in 13 queries.
# 7462 has been found in 8 queries.
# 3389 has been found in 13 queries.
# []

# %% [markdown]
# #### **Problem #2.5**
#
# **Together**, let's graph the worst number of queries for list sizes from 100 to 10000 *for both linear and binary search*.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  # COMPLETE THIS CODE

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
#   File "<ipython-input-36-6a3b8be9e6f3>", line 7
#     plt.scatter(ns, linear_queries, label = "linear")
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# 16 has been found in 6 queries.
# 46 has been found in 7 queries.
# 12 has been found in 3 queries.
# 55 has been found in 4 queries.
# 74 has been found in 2 queries.
# 88 has been found in 7 queries.
# 95 has been found in 5 queries.
# 58 has been found in 5 queries.
# 80 has been found in 4 queries.
# 91 has been found in 8 queries.
# 70 has been found in 6 queries.
# 165 has been found in 7 queries.
# 135 has been found in 8 queries.
# 156 has been found in 7 queries.
# 2 has been found in 8 queries.
# 160 has been found in 8 queries.
# 110 has been found in 8 queries.
# 162 has been found in 7 queries.
# 188 has been found in 8 queries.
# 5 has been found in 8 queries.
# 293 has been found in 9 queries.
# 224 has been found in 2 queries.
# 28 has been found in 8 queries.
# 7 has been found in 8 queries.
# 271 has been found in 8 queries.
# 160 has been found in 7 queries.
# 108 has been found in 7 queries.
# 13 has been found in 6 queries.
# 200 has been found in 6 queries.
# 219 has been found in 9 queries.
# 307 has been found in 9 queries.
# 354 has been found in 9 queries.
# 328 has been found in 8 queries.
# 156 has been found in 8 queries.
# 208 has been found in 7 queries.
# 267 has been found in 6 queries.
# 229 has been found in 9 queries.
# 317 has been found in 6 queries.
# 379 has been found in 9 queries.
# 475 has been found in 6 queries.
# 483 has been found in 5 queries.
# 494 has been found in 9 queries.
# 117 has been found in 9 queries.
# 405 has been found in 4 queries.
# 314 has been found in 7 queries.
# 444 has been found in 9 queries.
# 138 has been found in 9 queries.
# 147 has been found in 6 queries.
# 223 has been found in 8 queries.
# 366 has been found in 8 queries.
# 252 has been found in 9 queries.
# 251 has been found in 6 queries.
# 87 has been found in 7 queries.
# 191 has been found in 9 queries.
# 196 has been found in 9 queries.
# 470 has been found in 9 queries.
# 595 has been found in 9 queries.
# 302 has been found in 9 queries.
# 38 has been found in 9 queries.
# 431 has been found in 9 queries.
# 643 has been found in 10 queries.
# 82 has been found in 9 queries.
# 220 has been found in 9 queries.
# 310 has been found in 7 queries.
# 190 has been found in 9 queries.
# 16 has been found in 9 queries.
# 309 has been found in 10 queries.
# 565 has been found in 9 queries.
# 452 has been found in 7 queries.
# 282 has been found in 10 queries.
# 162 has been found in 9 queries.
# 487 has been found in 9 queries.
# 397 has been found in 9 queries.
# 44 has been found in 10 queries.
# 521 has been found in 10 queries.
# 129 has been found in 10 queries.
# 157 has been found in 10 queries.
# 91 has been found in 10 queries.
# 608 has been found in 8 queries.
# 99 has been found in 9 queries.
# 287 has been found in 7 queries.
# 780 has been found in 9 queries.
# 702 has been found in 5 queries.
# 293 has been found in 10 queries.
# 209 has been found in 10 queries.
# 187 has been found in 9 queries.
# 414 has been found in 9 queries.
# 112 has been found in 3 queries.
# 385 has been found in 7 queries.
# 874 has been found in 3 queries.
# 180 has been found in 9 queries.
# 125 has been found in 9 queries.
# 861 has been found in 10 queries.
# 333 has been found in 10 queries.
# 478 has been found in 10 queries.
# 850 has been found in 7 queries.
# 44 has been found in 9 queries.
# 544 has been found in 10 queries.
# 978 has been found in 10 queries.
# 35 has been found in 10 queries.
# 569 has been found in 10 queries.
# 57 has been found in 9 queries.
# 1016 has been found in 8 queries.
# 981 has been found in 10 queries.
# 910 has been found in 10 queries.
# 676 has been found in 11 queries.
# 386 has been found in 9 queries.
# 246 has been found in 10 queries.
# 40 has been found in 9 queries.
# 1068 has been found in 10 queries.
# 594 has been found in 8 queries.
# 598 has been found in 11 queries.
# 701 has been found in 7 queries.
# 936 has been found in 5 queries.
# 768 has been found in 10 queries.
# 950 has been found in 8 queries.
# 642 has been found in 9 queries.
# 88 has been found in 10 queries.
# 476 has been found in 7 queries.
# 676 has been found in 9 queries.
# 324 has been found in 2 queries.
# 898 has been found in 10 queries.
# 708 has been found in 11 queries.
# 1006 has been found in 9 queries.
# 984 has been found in 7 queries.
# 1295 has been found in 11 queries.
# 891 has been found in 11 queries.
# 1024 has been found in 7 queries.
# 741 has been found in 10 queries.
# 1366 has been found in 7 queries.
# 630 has been found in 9 queries.
# 802 has been found in 8 queries.
# 329 has been found in 9 queries.
# 857 has been found in 8 queries.
# 791 has been found in 8 queries.
# 432 has been found in 11 queries.
# 862 has been found in 11 queries.
# 686 has been found in 10 queries.
# 820 has been found in 10 queries.
# 823 has been found in 11 queries.
# 557 has been found in 11 queries.
# 1308 has been found in 9 queries.
# 445 has been found in 11 queries.
# 75 has been found in 8 queries.
# 105 has been found in 10 queries.
# 312 has been found in 9 queries.
# 965 has been found in 8 queries.
# 435 has been found in 10 queries.
# 920 has been found in 11 queries.
# 1217 has been found in 8 queries.
# 1333 has been found in 9 queries.
# 209 has been found in 10 queries.
# 1061 has been found in 7 queries.
# 239 has been found in 9 queries.
# 49 has been found in 5 queries.
# 1401 has been found in 11 queries.
# 1174 has been found in 6 queries.
# 867 has been found in 8 queries.
# 932 has been found in 11 queries.
# 884 has been found in 9 queries.
# 1488 has been found in 11 queries.
# 706 has been found in 10 queries.
# 1547 has been found in 11 queries.
# 331 has been found in 7 queries.
# 1617 has been found in 11 queries.
# 763 has been found in 11 queries.
# 1606 has been found in 10 queries.
# 834 has been found in 11 queries.
# 891 has been found in 9 queries.
# 1091 has been found in 9 queries.
# 1723 has been found in 11 queries.
# 1343 has been found in 10 queries.
# 1001 has been found in 11 queries.
# 1423 has been found in 11 queries.
# 231 has been found in 8 queries.
# 1164 has been found in 10 queries.
# 1266 has been found in 11 queries.
# 269 has been found in 9 queries.
# 1658 has been found in 6 queries.
# 1619 has been found in 9 queries.
# 1099 has been found in 9 queries.
# 1489 has been found in 11 queries.
# 832 has been found in 11 queries.
# 929 has been found in 11 queries.
# 140 has been found in 11 queries.
# 431 has been found in 11 queries.
# 1160 has been found in 11 queries.
# 602 has been found in 9 queries.
# 391 has been found in 8 queries.
# 637 has been found in 10 queries.
# 726 has been found in 11 queries.
# 1325 has been found in 11 queries.
# 51 has been found in 11 queries.
# 688 has been found in 11 queries.
# 1021 has been found in 11 queries.
# 1311 has been found in 5 queries.
# 1822 has been found in 9 queries.
# 1163 has been found in 11 queries.
# 1877 has been found in 9 queries.
# 917 has been found in 4 queries.
# 155 has been found in 8 queries.
# 1060 has been found in 11 queries.
# 1049 has been found in 1 queries.
# 948 has been found in 11 queries.
# 2029 has been found in 11 queries.
# 240 has been found in 11 queries.
# 53 has been found in 11 queries.
# 844 has been found in 10 queries.
# 1297 has been found in 11 queries.
# 1208 has been found in 11 queries.
# 1922 has been found in 11 queries.
# 1850 has been found in 9 queries.
# 332 has been found in 11 queries.
# 1798 has been found in 9 queries.
# 314 has been found in 10 queries.
# 1664 has been found in 11 queries.
# 1139 has been found in 10 queries.
# 951 has been found in 12 queries.
# 2188 has been found in 11 queries.
# 1811 has been found in 11 queries.
# 1822 has been found in 8 queries.
# 1099 has been found in 9 queries.
# 294 has been found in 11 queries.
# 18 has been found in 11 queries.
# 689 has been found in 12 queries.
# 1181 has been found in 10 queries.
# 1668 has been found in 11 queries.
# 47 has been found in 11 queries.
# 817 has been found in 11 queries.
# 347 has been found in 10 queries.
# 1742 has been found in 7 queries.
# 1889 has been found in 10 queries.
# 2348 has been found in 10 queries.
# 1399 has been found in 12 queries.
# 1339 has been found in 8 queries.
# 2254 has been found in 11 queries.
# 1228 has been found in 10 queries.
# 495 has been found in 8 queries.
# 202 has been found in 10 queries.
# 879 has been found in 10 queries.
# 2198 has been found in 11 queries.
# 1323 has been found in 11 queries.
# 558 has been found in 11 queries.
# 2074 has been found in 11 queries.
# 416 has been found in 10 queries.
# 1282 has been found in 12 queries.
# 313 has been found in 11 queries.
# 2310 has been found in 11 queries.
# 1413 has been found in 12 queries.
# 825 has been found in 12 queries.
# 148 has been found in 10 queries.
# 254 has been found in 11 queries.
# 2071 has been found in 11 queries.
# 795 has been found in 9 queries.
# 1756 has been found in 11 queries.
# 2004 has been found in 9 queries.
# 1021 has been found in 10 queries.
# 500 has been found in 12 queries.
# 2325 has been found in 11 queries.
# 2392 has been found in 8 queries.
# 1099 has been found in 12 queries.
# 1456 has been found in 10 queries.
# 597 has been found in 11 queries.
# 298 has been found in 12 queries.
# 1829 has been found in 12 queries.
# 2489 has been found in 10 queries.
# 1532 has been found in 9 queries.
# 2388 has been found in 11 queries.
# 1345 has been found in 12 queries.
# 989 has been found in 11 queries.
# 2003 has been found in 11 queries.
# 1249 has been found in 12 queries.
# 2111 has been found in 10 queries.
# 1065 has been found in 11 queries.
# 412 has been found in 11 queries.
# 362 has been found in 11 queries.
# 1445 has been found in 11 queries.
# 520 has been found in 12 queries.
# 2225 has been found in 11 queries.
# 2350 has been found in 11 queries.
# 342 has been found in 11 queries.
# 508 has been found in 8 queries.
# 66 has been found in 12 queries.
# 1575 has been found in 10 queries.
# 2656 has been found in 10 queries.
# 1828 has been found in 11 queries.
# 1352 has been found in 9 queries.
# 215 has been found in 11 queries.
# 902 has been found in 10 queries.
# 2072 has been found in 8 queries.
# 519 has been found in 9 queries.
# 1535 has been found in 12 queries.
# 544 has been found in 11 queries.
# 2025 has been found in 8 queries.
# 2804 has been found in 12 queries.
# 938 has been found in 10 queries.
# 2370 has been found in 12 queries.
# 246 has been found in 12 queries.
# 2911 has been found in 11 queries.
# 2410 has been found in 12 queries.
# 1419 has been found in 11 queries.
# 41 has been found in 12 queries.
# 158 has been found in 12 queries.
# 495 has been found in 8 queries.
# 1750 has been found in 12 queries.
# 1446 has been found in 11 queries.
# 1713 has been found in 12 queries.
# 1901 has been found in 12 queries.
# 1918 has been found in 11 queries.
# 2128 has been found in 11 queries.
# 232 has been found in 12 queries.
# 2367 has been found in 9 queries.
# 3135 has been found in 12 queries.
# 642 has been found in 9 queries.
# 306 has been found in 11 queries.
# 656 has been found in 11 queries.
# 2460 has been found in 12 queries.
# 2781 has been found in 11 queries.
# 1112 has been found in 11 queries.
# 3105 has been found in 11 queries.
# 2237 has been found in 10 queries.
# 1490 has been found in 12 queries.
# 3172 has been found in 10 queries.
# 1916 has been found in 12 queries.
# 2949 has been found in 12 queries.
# 1287 has been found in 6 queries.
# 306 has been found in 12 queries.
# 995 has been found in 11 queries.
# 925 has been found in 11 queries.
# 520 has been found in 12 queries.
# 742 has been found in 5 queries.
# 3066 has been found in 8 queries.
# 1914 has been found in 10 queries.
# 2580 has been found in 12 queries.
# 445 has been found in 12 queries.
# 420 has been found in 10 queries.
# 592 has been found in 10 queries.
# 1242 has been found in 12 queries.
# 2250 has been found in 11 queries.
# 1550 has been found in 9 queries.
# 1718 has been found in 12 queries.
# 1421 has been found in 11 queries.
# 3098 has been found in 12 queries.
# 2318 has been found in 10 queries.
# 595 has been found in 12 queries.
# 1377 has been found in 12 queries.
# 1622 has been found in 12 queries.
# 1332 has been found in 11 queries.
# 863 has been found in 10 queries.
# 2919 has been found in 12 queries.
# 2409 has been found in 12 queries.
# 798 has been found in 11 queries.
# 1408 has been found in 10 queries.
# 1901 has been found in 12 queries.
# 1802 has been found in 10 queries.
# 3039 has been found in 10 queries.
# 1818 has been found in 11 queries.
# 897 has been found in 11 queries.
# 1618 has been found in 12 queries.
# 1671 has been found in 10 queries.
# 1706 has been found in 12 queries.
# 2361 has been found in 12 queries.
# 547 has been found in 12 queries.
# 24 has been found in 10 queries.
# 257 has been found in 11 queries.
# 2231 has been found in 9 queries.
# 2773 has been found in 12 queries.
# 3088 has been found in 12 queries.
# 802 has been found in 11 queries.
# 799 has been found in 12 queries.
# 3403 has been found in 12 queries.
# 3436 has been found in 11 queries.
# 2416 has been found in 11 queries.
# 917 has been found in 11 queries.
# 2476 has been found in 12 queries.
# 820 has been found in 11 queries.
# 2669 has been found in 12 queries.
# 1062 has been found in 12 queries.
# 1719 has been found in 12 queries.
# 2387 has been found in 12 queries.
# 2616 has been found in 12 queries.
# 3634 has been found in 12 queries.
# 2792 has been found in 11 queries.
# 1583 has been found in 5 queries.
# 3196 has been found in 12 queries.
# 2086 has been found in 11 queries.
# 846 has been found in 11 queries.
# 3431 has been found in 11 queries.
# 2342 has been found in 11 queries.
# 1389 has been found in 8 queries.
# 2502 has been found in 10 queries.
# 3890 has been found in 12 queries.
# 3609 has been found in 12 queries.
# 1714 has been found in 12 queries.
# 1834 has been found in 9 queries.
# 1319 has been found in 12 queries.
# 670 has been found in 8 queries.
# 820 has been found in 11 queries.
# 3723 has been found in 11 queries.
# 2166 has been found in 12 queries.
# 1045 has been found in 12 queries.
# 3964 has been found in 11 queries.
# 2596 has been found in 12 queries.
# 2643 has been found in 11 queries.
# 2570 has been found in 12 queries.
# 1282 has been found in 11 queries.
# 3409 has been found in 12 queries.
# 73 has been found in 12 queries.
# 1296 has been found in 8 queries.
# 1129 has been found in 12 queries.
# 3134 has been found in 11 queries.
# 644 has been found in 11 queries.
# 1245 has been found in 6 queries.
# 3294 has been found in 11 queries.
# 3581 has been found in 11 queries.
# 3702 has been found in 10 queries.
# 2733 has been found in 12 queries.
# 357 has been found in 11 queries.
# 4151 has been found in 11 queries.
# 2300 has been found in 12 queries.
# 458 has been found in 11 queries.
# 4035 has been found in 12 queries.
# 1301 has been found in 11 queries.
# 1051 has been found in 12 queries.
# 629 has been found in 12 queries.
# 3662 has been found in 12 queries.
# 1323 has been found in 12 queries.
# 2454 has been found in 10 queries.
# 3830 has been found in 11 queries.
# 356 has been found in 11 queries.
# 3966 has been found in 12 queries.
# 850 has been found in 12 queries.
# 4090 has been found in 12 queries.
# 3159 has been found in 12 queries.
# 1378 has been found in 10 queries.
# 2677 has been found in 11 queries.
# 2861 has been found in 11 queries.
# 429 has been found in 12 queries.
# 1652 has been found in 12 queries.
# 1917 has been found in 10 queries.
# 2528 has been found in 12 queries.
# 2542 has been found in 10 queries.
# 3252 has been found in 11 queries.
# 2610 has been found in 11 queries.
# 982 has been found in 13 queries.
# 1306 has been found in 12 queries.
# 3869 has been found in 10 queries.
# 3087 has been found in 10 queries.
# 461 has been found in 12 queries.
# 1473 has been found in 12 queries.
# 1235 has been found in 11 queries.
# 2388 has been found in 8 queries.
# 2206 has been found in 11 queries.
# 2828 has been found in 13 queries.
# 1725 has been found in 12 queries.
# 3401 has been found in 11 queries.
# 2967 has been found in 10 queries.
# 4032 has been found in 9 queries.
# 3251 has been found in 8 queries.
# 1324 has been found in 10 queries.
# 2436 has been found in 12 queries.
# 757 has been found in 11 queries.
# 1479 has been found in 12 queries.
# 2410 has been found in 12 queries.
# 3145 has been found in 13 queries.
# 2903 has been found in 10 queries.
# 4670 has been found in 13 queries.
# 755 has been found in 10 queries.
# 997 has been found in 12 queries.
# 39 has been found in 11 queries.
# 2496 has been found in 10 queries.
# 3753 has been found in 10 queries.
# 1102 has been found in 11 queries.
# 4682 has been found in 12 queries.
# 332 has been found in 12 queries.
# 3651 has been found in 12 queries.
# 3784 has been found in 12 queries.
# 2467 has been found in 12 queries.
# 4743 has been found in 12 queries.
# 2064 has been found in 13 queries.
# 1184 has been found in 13 queries.
# 4836 has been found in 10 queries.
# 1585 has been found in 12 queries.
# 3821 has been found in 13 queries.
# 1712 has been found in 12 queries.
# 1905 has been found in 12 queries.
# 3088 has been found in 13 queries.
# 4018 has been found in 7 queries.
# 4684 has been found in 11 queries.
# 2176 has been found in 9 queries.
# 4148 has been found in 9 queries.
# 1683 has been found in 12 queries.
# 518 has been found in 11 queries.
# 4676 has been found in 9 queries.
# 2329 has been found in 11 queries.
# 70 has been found in 11 queries.
# 3438 has been found in 11 queries.
# 1765 has been found in 9 queries.
# 4655 has been found in 13 queries.
# 367 has been found in 9 queries.
# 3498 has been found in 12 queries.
# 3480 has been found in 10 queries.
# 662 has been found in 12 queries.
# 1678 has been found in 11 queries.
# 1242 has been found in 12 queries.
# 2116 has been found in 12 queries.
# 1790 has been found in 13 queries.
# 276 has been found in 12 queries.
# 2592 has been found in 13 queries.
# 961 has been found in 12 queries.
# 3135 has been found in 13 queries.
# 4707 has been found in 13 queries.
# 1606 has been found in 12 queries.
# 1941 has been found in 12 queries.
# 3649 has been found in 10 queries.
# 3136 has been found in 9 queries.
# 3702 has been found in 11 queries.
# 685 has been found in 12 queries.
# 1649 has been found in 10 queries.
# 832 has been found in 10 queries.
# 1385 has been found in 8 queries.
# 1961 has been found in 13 queries.
# 4629 has been found in 13 queries.
# 1475 has been found in 11 queries.
# 60 has been found in 13 queries.
# 1651 has been found in 13 queries.
# 3136 has been found in 11 queries.
# 2517 has been found in 13 queries.
# 928 has been found in 12 queries.
# 4926 has been found in 12 queries.
# 3576 has been found in 12 queries.
# 4200 has been found in 13 queries.
# 5126 has been found in 11 queries.
# 961 has been found in 13 queries.
# 444 has been found in 11 queries.
# 3269 has been found in 12 queries.
# 1428 has been found in 12 queries.
# 2906 has been found in 11 queries.
# 2194 has been found in 11 queries.
# 499 has been found in 12 queries.
# 598 has been found in 11 queries.
# 342 has been found in 13 queries.
# 2852 has been found in 11 queries.
# 4036 has been found in 12 queries.
# 4764 has been found in 13 queries.
# 4134 has been found in 9 queries.
# 282 has been found in 13 queries.
# 486 has been found in 13 queries.
# 4432 has been found in 12 queries.
# 5328 has been found in 12 queries.
# 755 has been found in 11 queries.
# 3816 has been found in 9 queries.
# 4905 has been found in 12 queries.
# 3471 has been found in 10 queries.
# 234 has been found in 12 queries.
# 1467 has been found in 12 queries.
# 3685 has been found in 12 queries.
# 1314 has been found in 12 queries.
# 2890 has been found in 13 queries.
# 4653 has been found in 12 queries.
# 428 has been found in 12 queries.
# 5607 has been found in 12 queries.
# 5181 has been found in 12 queries.
# 3138 has been found in 8 queries.
# 4829 has been found in 13 queries.
# 1649 has been found in 12 queries.
# 4205 has been found in 13 queries.
# 3781 has been found in 12 queries.
# 864 has been found in 11 queries.
# 4931 has been found in 10 queries.
# 674 has been found in 13 queries.
# 713 has been found in 12 queries.
# 2881 has been found in 10 queries.
# 4794 has been found in 13 queries.
# 2286 has been found in 8 queries.
# 1741 has been found in 13 queries.
# 3320 has been found in 12 queries.
# 3805 has been found in 5 queries.
# 694 has been found in 13 queries.
# 3852 has been found in 10 queries.
# 5025 has been found in 12 queries.
# 4003 has been found in 12 queries.
# 960 has been found in 13 queries.
# 2289 has been found in 12 queries.
# 465 has been found in 10 queries.
# 3915 has been found in 13 queries.
# 3423 has been found in 11 queries.
# 3125 has been found in 12 queries.
# 1950 has been found in 13 queries.
# 5633 has been found in 12 queries.
# 227 has been found in 10 queries.
# 5951 has been found in 13 queries.
# 7 has been found in 13 queries.
# 5882 has been found in 12 queries.
# 384 has been found in 13 queries.
# 2922 has been found in 10 queries.
# 3804 has been found in 12 queries.
# 866 has been found in 12 queries.
# 4448 has been found in 13 queries.
# 3848 has been found in 13 queries.
# 5435 has been found in 13 queries.
# 3303 has been found in 13 queries.
# 5329 has been found in 13 queries.
# 1509 has been found in 11 queries.
# 5280 has been found in 12 queries.
# 2284 has been found in 12 queries.
# 4487 has been found in 11 queries.
# 2878 has been found in 11 queries.
# 5879 has been found in 12 queries.
# 3348 has been found in 13 queries.
# 5202 has been found in 11 queries.
# 3707 has been found in 11 queries.
# 622 has been found in 10 queries.
# 6178 has been found in 12 queries.
# 1224 has been found in 11 queries.
# 2027 has been found in 12 queries.
# 3894 has been found in 13 queries.
# 6079 has been found in 13 queries.
# 630 has been found in 13 queries.
# 3252 has been found in 13 queries.
# 1513 has been found in 13 queries.
# 2992 has been found in 12 queries.
# 5050 has been found in 13 queries.
# 2540 has been found in 12 queries.
# 122 has been found in 8 queries.
# 5409 has been found in 13 queries.
# 5492 has been found in 10 queries.
# 3791 has been found in 11 queries.
# 5784 has been found in 11 queries.
# 3749 has been found in 7 queries.
# 5941 has been found in 13 queries.
# 3856 has been found in 12 queries.
# 5791 has been found in 13 queries.
# 2998 has been found in 13 queries.
# 3801 has been found in 13 queries.
# 3761 has been found in 9 queries.
# 1620 has been found in 11 queries.
# 5674 has been found in 8 queries.
# 4112 has been found in 12 queries.
# 5354 has been found in 13 queries.
# 6399 has been found in 13 queries.
# 4869 has been found in 13 queries.
# 940 has been found in 13 queries.
# 3532 has been found in 13 queries.
# 4234 has been found in 11 queries.
# 8 has been found in 13 queries.
# 3233 has been found in 13 queries.
# 182 has been found in 13 queries.
# 1269 has been found in 12 queries.
# 3913 has been found in 11 queries.
# 2694 has been found in 13 queries.
# 4280 has been found in 13 queries.
# 2857 has been found in 13 queries.
# 3821 has been found in 12 queries.
# 652 has been found in 11 queries.
# 6434 has been found in 12 queries.
# 2511 has been found in 13 queries.
# 5070 has been found in 10 queries.
# 2645 has been found in 12 queries.
# 3063 has been found in 11 queries.
# 4023 has been found in 13 queries.
# 2072 has been found in 12 queries.
# 3727 has been found in 9 queries.
# 6288 has been found in 13 queries.
# 6656 has been found in 13 queries.
# 5554 has been found in 13 queries.
# 4002 has been found in 8 queries.
# 1349 has been found in 11 queries.
# 6003 has been found in 13 queries.
# 2293 has been found in 13 queries.
# 1197 has been found in 12 queries.
# 891 has been found in 11 queries.
# 3615 has been found in 12 queries.
# 304 has been found in 9 queries.
# 3746 has been found in 11 queries.
# 2549 has been found in 3 queries.
# 3164 has been found in 13 queries.
# 3867 has been found in 13 queries.
# 465 has been found in 13 queries.
# 2484 has been found in 10 queries.
# 2401 has been found in 12 queries.
# 627 has been found in 13 queries.
# 1134 has been found in 11 queries.
# 220 has been found in 13 queries.
# 1857 has been found in 13 queries.
# 5661 has been found in 11 queries.
# 5004 has been found in 13 queries.
# 6698 has been found in 13 queries.
# 135 has been found in 12 queries.
# 5707 has been found in 12 queries.
# 2544 has been found in 11 queries.
# 3104 has been found in 11 queries.
# 6950 has been found in 10 queries.
# 4841 has been found in 11 queries.
# 5286 has been found in 13 queries.
# 3861 has been found in 12 queries.
# 5850 has been found in 7 queries.
# 2726 has been found in 10 queries.
# 3144 has been found in 13 queries.
# 2853 has been found in 12 queries.
# 40 has been found in 13 queries.
# 2523 has been found in 12 queries.
# 5934 has been found in 12 queries.
# 3602 has been found in 12 queries.
# 2071 has been found in 10 queries.
# 766 has been found in 13 queries.
# 1548 has been found in 11 queries.
# 393 has been found in 13 queries.
# 5855 has been found in 12 queries.
# 231 has been found in 10 queries.
# 693 has been found in 12 queries.
# 2141 has been found in 12 queries.
# 5144 has been found in 13 queries.
# 4986 has been found in 13 queries.
# 3222 has been found in 11 queries.
# 4208 has been found in 12 queries.
# 6575 has been found in 13 queries.
# 1885 has been found in 13 queries.
# 535 has been found in 13 queries.
# 2809 has been found in 13 queries.
# 4560 has been found in 13 queries.
# 1146 has been found in 13 queries.
# 5514 has been found in 12 queries.
# 246 has been found in 13 queries.
# 6745 has been found in 11 queries.
# 2684 has been found in 12 queries.
# 5608 has been found in 13 queries.
# 1347 has been found in 12 queries.
# 5524 has been found in 13 queries.
# 7202 has been found in 13 queries.
# 3554 has been found in 8 queries.
# 3583 has been found in 6 queries.
# 616 has been found in 11 queries.
# 4243 has been found in 11 queries.
# 4639 has been found in 12 queries.
# 3747 has been found in 13 queries.
# 2224 has been found in 8 queries.
# 934 has been found in 11 queries.
# 3328 has been found in 13 queries.
# 6791 has been found in 11 queries.
# 1857 has been found in 12 queries.
# 3902 has been found in 10 queries.
# 5714 has been found in 11 queries.
# 4549 has been found in 11 queries.
# 2501 has been found in 13 queries.
# 1356 has been found in 11 queries.
# 2188 has been found in 13 queries.
# 2401 has been found in 12 queries.
# 6283 has been found in 13 queries.
# 4880 has been found in 13 queries.
# 775 has been found in 12 queries.
# 488 has been found in 9 queries.
# 6354 has been found in 11 queries.
# 210 has been found in 11 queries.
# 6241 has been found in 12 queries.
# 1504 has been found in 10 queries.
# 3930 has been found in 13 queries.
# 4584 has been found in 13 queries.
# 6450 has been found in 13 queries.
# 7583 has been found in 12 queries.
# 7375 has been found in 13 queries.
# 7507 has been found in 13 queries.
# 2332 has been found in 11 queries.
# 4261 has been found in 10 queries.
# 3553 has been found in 13 queries.
# 2270 has been found in 12 queries.
# 1031 has been found in 12 queries.
# 6505 has been found in 13 queries.
# 2086 has been found in 13 queries.
# 7652 has been found in 13 queries.
# 1416 has been found in 12 queries.
# 4979 has been found in 9 queries.
# 3007 has been found in 13 queries.
# 5080 has been found in 12 queries.
# 803 has been found in 13 queries.
# 5772 has been found in 9 queries.
# 7147 has been found in 13 queries.
# 4577 has been found in 13 queries.
# 7161 has been found in 11 queries.
# 6931 has been found in 12 queries.
# 5640 has been found in 12 queries.
# 5996 has been found in 11 queries.
# 2465 has been found in 12 queries.
# 3110 has been found in 13 queries.
# 2364 has been found in 12 queries.
# 3444 has been found in 13 queries.
# 2283 has been found in 13 queries.
# 1591 has been found in 11 queries.
# 3898 has been found in 11 queries.
# 2837 has been found in 13 queries.
# 7480 has been found in 13 queries.
# 6073 has been found in 13 queries.
# 893 has been found in 11 queries.
# 7180 has been found in 12 queries.
# 5015 has been found in 13 queries.
# 653 has been found in 12 queries.
# 3279 has been found in 13 queries.
# 3196 has been found in 13 queries.
# 1289 has been found in 12 queries.
# 4644 has been found in 13 queries.
# 1644 has been found in 6 queries.
# 215 has been found in 12 queries.
# 5355 has been found in 12 queries.
# 2171 has been found in 12 queries.
# 4127 has been found in 9 queries.
# 3014 has been found in 12 queries.
# 3891 has been found in 13 queries.
# 6762 has been found in 13 queries.
# 3224 has been found in 13 queries.
# 2945 has been found in 6 queries.
# 4870 has been found in 13 queries.
# 7162 has been found in 13 queries.
# 8010 has been found in 11 queries.
# 7759 has been found in 13 queries.
# 2824 has been found in 13 queries.
# 5240 has been found in 11 queries.
# 8185 has been found in 13 queries.
# 562 has been found in 12 queries.
# 1053 has been found in 13 queries.
# 432 has been found in 11 queries.
# 5581 has been found in 12 queries.
# 1273 has been found in 12 queries.
# 726 has been found in 12 queries.
# 3055 has been found in 13 queries.
# 4763 has been found in 8 queries.
# 3284 has been found in 11 queries.
# 918 has been found in 13 queries.
# 5203 has been found in 13 queries.
# 5027 has been found in 11 queries.
# 522 has been found in 13 queries.
# 8043 has been found in 12 queries.
# 3984 has been found in 9 queries.
# 6969 has been found in 12 queries.
# 6887 has been found in 13 queries.
# 6296 has been found in 12 queries.
# 3902 has been found in 14 queries.
# 227 has been found in 13 queries.
# 8057 has been found in 11 queries.
# 1415 has been found in 12 queries.
# 6648 has been found in 13 queries.
# 5367 has been found in 13 queries.
# 2475 has been found in 11 queries.
# 3294 has been found in 13 queries.
# 5043 has been found in 13 queries.
# 3316 has been found in 13 queries.
# 2709 has been found in 13 queries.
# 6843 has been found in 13 queries.
# 866 has been found in 11 queries.
# 2034 has been found in 12 queries.
# 6126 has been found in 12 queries.
# 3987 has been found in 10 queries.
# 7658 has been found in 6 queries.
# 4594 has been found in 13 queries.
# 4638 has been found in 11 queries.
# 8100 has been found in 12 queries.
# 7483 has been found in 12 queries.
# 4806 has been found in 11 queries.
# 4600 has been found in 8 queries.
# 1684 has been found in 12 queries.
# 1399 has been found in 13 queries.
# 6738 has been found in 13 queries.
# 308 has been found in 13 queries.
# 3145 has been found in 13 queries.
# 8466 has been found in 13 queries.
# 5527 has been found in 12 queries.
# 3432 has been found in 13 queries.
# 1243 has been found in 11 queries.
# 4318 has been found in 13 queries.
# 1325 has been found in 13 queries.
# 1824 has been found in 11 queries.
# 7311 has been found in 10 queries.
# 5517 has been found in 13 queries.
# 2767 has been found in 13 queries.
# 1479 has been found in 13 queries.
# 1547 has been found in 12 queries.
# 7017 has been found in 12 queries.
# 1763 has been found in 11 queries.
# 856 has been found in 13 queries.
# 5356 has been found in 11 queries.
# 2667 has been found in 13 queries.
# 4461 has been found in 11 queries.
# 103 has been found in 14 queries.
# 8541 has been found in 10 queries.
# 8637 has been found in 9 queries.
# 8367 has been found in 10 queries.
# 6646 has been found in 13 queries.
# 8609 has been found in 13 queries.
# 242 has been found in 14 queries.
# 7138 has been found in 13 queries.
# 3688 has been found in 13 queries.
# 7505 has been found in 12 queries.
# 6714 has been found in 13 queries.
# 7114 has been found in 12 queries.
# 3539 has been found in 14 queries.
# 248 has been found in 13 queries.
# 414 has been found in 12 queries.
# 2897 has been found in 14 queries.
# 4201 has been found in 12 queries.
# 959 has been found in 13 queries.
# 1182 has been found in 13 queries.
# 3147 has been found in 11 queries.
# 68 has been found in 12 queries.
# 5741 has been found in 12 queries.
# 1930 has been found in 11 queries.
# 6778 has been found in 14 queries.
# 1668 has been found in 14 queries.
# 3940 has been found in 13 queries.
# 756 has been found in 12 queries.
# 1803 has been found in 13 queries.
# 2809 has been found in 13 queries.
# 8319 has been found in 13 queries.
# 3075 has been found in 11 queries.
# 8902 has been found in 10 queries.
# 2234 has been found in 13 queries.
# 4682 has been found in 13 queries.
# 4047 has been found in 12 queries.
# 669 has been found in 12 queries.
# 2442 has been found in 6 queries.
# 6989 has been found in 13 queries.
# 3802 has been found in 14 queries.
# 2508 has been found in 13 queries.
# 7553 has been found in 13 queries.
# 8905 has been found in 13 queries.
# 4345 has been found in 12 queries.
# 2449 has been found in 14 queries.
# 3271 has been found in 11 queries.
# 5377 has been found in 12 queries.
# 7371 has been found in 14 queries.
# 2992 has been found in 12 queries.
# 8607 has been found in 14 queries.
# 2863 has been found in 13 queries.
# 378 has been found in 13 queries.
# 7001 has been found in 14 queries.
# 4347 has been found in 13 queries.
# 2534 has been found in 13 queries.
# 2364 has been found in 12 queries.
# 534 has been found in 13 queries.
# 797 has been found in 13 queries.
# 7376 has been found in 13 queries.
# 4666 has been found in 12 queries.
# 6172 has been found in 13 queries.
# 5592 has been found in 13 queries.
# 8302 has been found in 13 queries.
# 2006 has been found in 11 queries.
# 1552 has been found in 11 queries.
# 4264 has been found in 13 queries.
# 7082 has been found in 13 queries.
# 6536 has been found in 12 queries.
# 7650 has been found in 14 queries.
# 1789 has been found in 10 queries.
# 3590 has been found in 13 queries.
# 3939 has been found in 13 queries.
# 8324 has been found in 7 queries.
# 6687 has been found in 11 queries.
# 2118 has been found in 13 queries.
# 4835 has been found in 14 queries.
# 6983 has been found in 10 queries.
# 2480 has been found in 12 queries.
# 5702 has been found in 13 queries.
# 7414 has been found in 14 queries.
# 7444 has been found in 9 queries.
# 7710 has been found in 13 queries.
# 6962 has been found in 12 queries.
# 9371 has been found in 11 queries.
# 5837 has been found in 11 queries.
# 8738 has been found in 12 queries.
# 1199 has been found in 12 queries.
# 5740 has been found in 13 queries.
# 1054 has been found in 14 queries.
# 5104 has been found in 11 queries.
# 5996 has been found in 13 queries.
# 968 has been found in 13 queries.
# 7982 has been found in 12 queries.
# 1394 has been found in 13 queries.
# 5037 has been found in 11 queries.
# 5649 has been found in 11 queries.
# 8309 has been found in 11 queries.
# 2546 has been found in 12 queries.
# 8611 has been found in 14 queries.
# 5117 has been found in 11 queries.
# 514 has been found in 14 queries.
# 23 has been found in 11 queries.
# 8431 has been found in 13 queries.
# 5106 has been found in 13 queries.
# 2932 has been found in 11 queries.
# 8747 has been found in 10 queries.
# 6492 has been found in 12 queries.
# 4509 has been found in 12 queries.
# 136 has been found in 12 queries.
# []

# %% [markdown]
# #### **Problem  #2.6**
#
# **Together**, let's see how the performance of binary and linear search change when the order of items in the list is random using the `random.sample(...)` function. We will do this in 3 steps:
#
# 1. Rewrite the `linear_search` function so that the list is randomly ordered.
# 2. Rewrite the `binary_search` function so that the list is randomly ordered.
# 3. Graph the average number of queries for both search algorithms.
#
# ---

# %% [markdown]
# ##### **Problem 2.6.1**
# Rewrite the `linear_search` function so that the list is randomly ordered.

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = # COMPLETE THIS LINE

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ###### **Solution**

# %%
def linear_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)
    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      if item == marked_item:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ##### **Problem #2.6.2**
# Rewrite the `binary_search` function so that the list is randomly ordered.

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = # COMPLETE THIS LINE

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ###### **Solution**

# %%
def binary_search(n):

  number_trials = 10
  worst_query = 0
  list_items = random.sample(range(n), n)

  for i in range(number_trials):

    marked_item = random.choice(list_items)

    left = 0
    right = len(list_items) - 1

    number_queries = 0
    for item in list_items:

      number_queries = number_queries + 1

      middle = int((left + right)/2)
      if list_items[middle] > marked_item:
        right = middle
      elif list_items[middle] < marked_item:
        left = middle
      else:
        #print(str(marked_item) + " has been found in " + str(number_queries) + " queries.")
        break

    worst_query = max(worst_query, number_queries)

  return worst_query

# %% [markdown]
# ##### **Problem #2.6.3**
# Graph the average number of queries for both search algorithms.

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  # COMPLETE THIS CODE

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()

# %% [markdown]
# ###### **Solution**

# %%
linear_queries = []
binary_queries = []
ns = range(100, 10000, 100)
for n in ns:
  linear_queries += [linear_search(n)]
  binary_queries += [binary_search(n)]

plt.scatter(ns, linear_queries, label = "linear")
plt.scatter(ns, binary_queries, label = "binary")

plt.xlabel("n")
plt.ylabel("Worst Number of Queries")
plt.title("Linear and Binary Search Worst Number of Queries with Increasing List Size")
plt.legend()

plt.plot()
# Out:
# []

# %% [markdown]
# #End of Lab
# ---
# © 2024 The Coding School, All rights reserved
